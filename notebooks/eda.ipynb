# %%
import pandas as pd
import numpy as np
from scipy import stats
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio

# Set the default template to 'plotly_dark' for all Plotly figures
pio.templates.default = 'plotly_dark'

import sys
import os
sys.path.append(os.path.abspath("../"))
from src.functions import *

# %% [markdown]
# ### Step 1: Analyse high level details like shape, null values, data types and basic statistics

# %%
path = "../data/raw/customer_segmentation_data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    id  age  gender  income  spending_score  membership_years  \
# 0   1   38  Female   99342              90                 3
# 1   2   21  Female   78852              60                 2
# 2   3   60  Female  126573              30                 2
# 3   4   40   Other   47099              74                 9
# 4   5   65  Female  140621              21                 3
#
#    purchase_frequency preferred_category  last_purchase_amount
# 0                  24          Groceries                113.53
# 1                  42             Sports                 41.93
# 2                  28           Clothing                424.36
# 3                   5      Home & Garden                991.93
# 4                  25        Electronics                347.08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1000 non-null   int64
#  1   age                   1000 non-null   int64
#  2   gender                1000 non-null   object
#  3   income                1000 non-null   int64
#  4   spending_score        1000 non-null   int64
#  5   membership_years      1000 non-null   int64
#  6   purchase_frequency    1000 non-null   int64
#  7   preferred_category    1000 non-null   object
#  8   last_purchase_amount  1000 non-null   float64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 70.4+ KB

# %%
df.id.nunique()
# Out:
# 1000

# %%
df = df.set_index("id")
df.head()
# Out:
#     age  gender  income  spending_score  membership_years  purchase_frequency  \
# id
# 1    38  Female   99342              90                 3                  24
# 2    21  Female   78852              60                 2                  42
# 3    60  Female  126573              30                 2                  28
# 4    40   Other   47099              74                 9                   5
# 5    65  Female  140621              21                 3                  25
#
#    preferred_category  last_purchase_amount
# id
# 1           Groceries                113.53
# 2              Sports                 41.93
# 3            Clothing                424.36
# 4       Home & Garden                991.93
# 5         Electronics                347.08

# %%
df.describe()
# Out:
#                age         income  spending_score  membership_years  \
# count  1000.000000    1000.000000     1000.000000        1000.00000
# mean     43.783000   88500.800000       50.685000           5.46900
# std      15.042213   34230.771122       28.955175           2.85573
# min      18.000000   30004.000000        1.000000           1.00000
# 25%      30.000000   57911.750000       26.000000           3.00000
# 50%      45.000000   87845.500000       50.000000           5.00000
# 75%      57.000000  116110.250000       76.000000           8.00000
# max      69.000000  149973.000000      100.000000          10.00000
#
#        purchase_frequency  last_purchase_amount
# count         1000.000000           1000.000000
# mean            26.596000            492.348670
# std             14.243654            295.744253
# min              1.000000             10.400000
# 25%             15.000000            218.762500
# 50%             27.000000            491.595000
# 75%             39.000000            747.170000
# max             50.000000            999.740000

# %% [markdown]
# ### Step 2: Categorize some features

# %%
# Set existing categories as the 'category' data type.
df['gender'] = df['gender'].astype('category')
df['preferred_category'] = df['preferred_category'].astype('category')

# Create buckets for different age ranges.
df['age_range'] = pd.cut(df['age'], [0, 20, 30, 40, 50, 60, 70])

# Create categories for low, medium and high income customers.
low = df['income'].quantile(.25)
medium = df['income'].quantile(.75)
high = df['income'].quantile(1)
df['income_level'] = pd.cut(df['income'], [0, low, medium, high], labels=['Low', 'Medium', 'High'])
df.income_level.value_counts()

df.dtypes
# Out:
# age                        int64
# gender                  category
# income                     int64
# spending_score             int64
# membership_years           int64
# purchase_frequency         int64
# preferred_category      category
# last_purchase_amount     float64
# age_range               category
# income_level            category
# dtype: object

# %% [markdown]
# ### Step 2: Split the data into numerical and categorical dataframes

# %%
num_cols = df.select_dtypes("number").columns.tolist()
cat_cols = df.select_dtypes("object").columns.tolist()
cat = df.select_dtypes('category')

num_df = df[num_cols].copy()
cat_df = df[cat_cols].copy()

# %% [markdown]
# ### Step 3: Visualize univariate data.

# %%
fig = make_subplots(rows=1, cols=len(cat.columns))

for i, col in enumerate(cat.columns):
    x = df[col].astype(str)
    y = df[col].value_counts()
    fig.add_trace(go.Bar(x=x.unique(), y=y, name=col), row=1, col=i+1)

fig.show()

# %%
fig = make_subplots(rows=1, cols=len(cat_df.columns))

for i, col in enumerate(cat_df.columns):
    x = df[col]
    fig.add_trace(go.Histogram(x=x, name=col), row=1, col=i+1)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 fig = make_subplots(rows=1, cols=len(cat_df.columns))
#       3 for i, col in enumerate(cat_df.columns):
#       4     x = df[col]
#
# File ~/Projects/customer_segmentation/cust-seg-venv/lib/python3.9/site-packages/plotly/subplots.py:305, in make_subplots(rows, cols, shared_xaxes, shared_yaxes, start_cell, print_grid, horizontal_spacing, vertical_spacing, subplot_titles, column_widths, row_heights, specs, insets, column_titles, row_titles, x_title, y_title, figure, **kwargs)
#       6 def make_subplots(
#       7     rows=1,
#       8     cols=1,
#    (...)
#      25     **kwargs,
#      26 ) -> go.Figure:
#      27     """
#      28     Return an instance of plotly.graph_objs.Figure with predefined subplots
#      29     configured in 'layout'.
#    (...)
#     302     Figure(...)
#     303     """
# --> 305     return _sub.make_subplots(
#     306         rows,
#     307         cols,
#     308         shared_xaxes,
#     309         shared_yaxes,
#     310         start_cell,
#     311         print_grid,
#     312         horizontal_spacing,
#     313         vertical_spacing,
#     314         subplot_titles,
#     315         column_widths,
#     316         row_heights,
#     317         specs,
#     318         insets,
#     319         column_titles,
#     320         row_titles,
#     321         x_title,
#     322         y_title,
#     323         figure,
#     324         **kwargs,
#     325     )
#
# File ~/Projects/customer_segmentation/cust-seg-venv/lib/python3.9/site-packages/plotly/_subplots.py:370, in make_subplots(rows, cols, shared_xaxes, shared_yaxes, start_cell, print_grid, horizontal_spacing, vertical_spacing, subplot_titles, column_widths, row_heights, specs, insets, column_titles, row_titles, x_title, y_title, figure, **kwargs)
#     368     #  ### cols ###
#     369     if not isinstance(cols, int) or cols <= 0:
# --> 370         raise ValueError(
#     371             """
#     372 The 'cols' argument to make_subplots must be an int greater than 0.
#     373     Received value of type {typ}: {val}""".format(
#     374                 typ=type(cols), val=repr(cols)
#     375             )
#     376         )
#     378     # ### start_cell ###
#     379     if start_cell == "bottom-left":
#
# ValueError:
# The 'cols' argument to make_subplots must be an int greater than 0.
#     Received value of type <class 'int'>: 0

# %%
fig = make_subplots(rows=1, cols=len(num_df.columns))

for i, col in enumerate(num_df.columns):
    x = df[col]
    fig.add_trace(go.Histogram(x=x, name=col), row=1, col=i+1)

fig.show()

# %%
# Standardizing the DataFrame using scipy's zscore in order to view multiple box plots on the same scale.
num_df_standardized = num_df.apply(stats.zscore)

fig = px.box(num_df_standardized)
fig.show()

# %%
# The scipy skewtest / kurtosistest checks the skewness / kurtosis against that of a normal distribution. It returns the statistic (z-score) and p-value.
# the optional 'alternative' parameter accepts {‘two-sided’, ‘less’, ‘greater’}
#‘two-sided’: the skewtest / kurtosistest of the distribution underlying the sample is different from that of the normal distribution (i.e. 0)
#‘less’: the skewtest / kurtosistest of the distribution underlying the sample is less than that of the normal distribution
#‘greater’: the skewtest / kurtosistest of the distribution underlying the sample is greater than that of the normal distribution

# This line uses a custom function from src/functions.py
shape(num_df)
# Out:
#                           skew  skew_pval  kurtosis      kurt_pval  \
# column
# age                  -0.045931   0.550488 -1.192708  6.315498e-153
# income                0.050988   0.507532 -1.167468  3.886531e-127
# spending_score       -0.016552   0.829571 -1.215929  2.487135e-184
# membership_years      0.029799   0.698418 -1.206557  1.461831e-170
# purchase_frequency   -0.083840   0.276384 -1.130455   1.757941e-99
# last_purchase_amount  0.017527   0.819704 -1.273612   0.000000e+00
#
#                       shap_wilks_norm_pval  normaltest_pval
# column
# age                           3.767758e-17    1.747195e-151
# income                        1.974271e-16    9.396633e-126
# spending_score                3.109461e-17    8.829289e-183
# membership_years              2.969011e-20    4.737741e-169
# purchase_frequency            1.772838e-16     2.585242e-98
# last_purchase_amount          9.703650e-19     0.000000e+00

# %% [markdown]
# ### Step 4: Investigate bivariate data

# %%
pd.crosstab(df.gender, df.preferred_category)
# Out:
# preferred_category  Clothing  Electronics  Groceries  Home & Garden  Sports
# gender
# Female                    56           65         66             68      61
# Male                      56           76         71             77      77
# Other                     58           74         62             61      72

# %%
num_df.corr()
# Out:
#                            age    income  spending_score  membership_years  \
# age                   1.000000 -0.000688        0.017707         -0.003431
# income               -0.000688  1.000000        0.000020         -0.035783
# spending_score        0.017707  0.000020        1.000000          0.026726
# membership_years     -0.003431 -0.035783        0.026726          1.000000
# purchase_frequency   -0.030137  0.000533        0.006708          0.069532
# last_purchase_amount  0.061599 -0.054006       -0.014475         -0.014135
#
#                       purchase_frequency  last_purchase_amount
# age                            -0.030137              0.061599
# income                          0.000533             -0.054006
# spending_score                  0.006708             -0.014475
# membership_years                0.069532             -0.014135
# purchase_frequency              1.000000              0.024400
# last_purchase_amount            0.024400              1.000000

# %%
levene_kruskal = analyze_group_differences(df, 'preferred_category', num_cols)
levene_kruskal_df = pd.DataFrame(levene_kruskal).set_index('column')

# Set test threshold.
threshold = 0.05

levene_kruskal_df['levene_hypothesis'] = np.where(levene_kruskal_df['levene_pvalue'] > threshold, 'null', 'alternative')
levene_kruskal_df['kruskal_hypothesis'] = np.where(levene_kruskal_df['kruskal_pvalue'] > threshold, 'null', 'alternative')

levene_kruskal_df
# Out:
#                       levene_statistic  levene_pvalue  kruskal_statistic  \
# column
# age                           0.274134       0.894728           1.924813
# income                        2.064232       0.083623           1.297917
# spending_score                1.067467       0.371435           0.601538
# membership_years              1.149464       0.331915           4.279576
# purchase_frequency            1.768900       0.133038           1.815715
# last_purchase_amount          0.503785       0.732978           1.858240
#
#                       kruskal_pvalue levene_hypothesis kruskal_hypothesis
# column
# age                         0.749586              null               null
# income                      0.861729              null               null
# spending_score              0.962893              null               null
# membership_years            0.369490              null               null
# purchase_frequency          0.769606              null               null
# last_purchase_amount        0.761812              null               null

# %%
levene_kruskal = analyze_group_differences(df, 'gender', num_cols)
levene_kruskal_df = pd.DataFrame(levene_kruskal).set_index('column')

# Set test threshold.
threshold = 0.05

levene_kruskal_df['levene_hypothesis'] = np.where(levene_kruskal_df['levene_pvalue'] > threshold, 'null', 'alternative')
levene_kruskal_df['kruskal_hypothesis'] = np.where(levene_kruskal_df['kruskal_pvalue'] > threshold, 'null', 'alternative')

levene_kruskal_df
# Out:
#                       levene_statistic  levene_pvalue  kruskal_statistic  \
# column
# age                           0.198883       0.819680           5.108750
# income                        4.249651       0.014543           0.124708
# spending_score                0.016435       0.983699           2.176718
# membership_years              0.097959       0.906696           1.687392
# purchase_frequency            1.786107       0.168177           5.754787
# last_purchase_amount          2.700623       0.067682           6.511215
#
#                       kruskal_pvalue levene_hypothesis kruskal_hypothesis
# column
# age                         0.077741              null               null
# income                      0.939550       alternative               null
# spending_score              0.336769              null               null
# membership_years            0.430118              null               null
# purchase_frequency          0.056281              null               null
# last_purchase_amount        0.038557              null        alternative

# %%
sample = np.random.choice(df.index, size=1000)
sample_data = df.loc[sample]

fig = px.scatter_matrix(
    sample_data,
    dimensions=['purchase_frequency', 'last_purchase_amount', 'income'],
    color="gender"
    )

fig.show()

# %%
levene_kruskal = analyze_group_differences(df, 'age_range', num_cols)
levene_kruskal_df = pd.DataFrame(levene_kruskal).set_index('column')

# Set test threshold.
threshold = 0.05

levene_kruskal_df['levene_hypothesis'] = np.where(levene_kruskal_df['levene_pvalue'] > threshold, 'null', 'alternative')
levene_kruskal_df['kruskal_hypothesis'] = np.where(levene_kruskal_df['kruskal_pvalue'] > threshold, 'null', 'alternative')

levene_kruskal_df
# Out:
# /Users/anthonydillon/Projects/customer_segmentation/src/functions.py:36: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#                       levene_statistic  levene_pvalue  kruskal_statistic  \
# column
# age                          18.249794   3.768311e-16         355.235505
# income                        1.374941   2.329566e-01           2.877662
# spending_score                0.421673   8.335887e-01           7.934197
# membership_years              1.278624   2.724519e-01           3.693891
# purchase_frequency            0.312125   9.056007e-01           3.266358
# last_purchase_amount          1.024791   4.027265e-01           5.393837
#
#                       kruskal_pvalue levene_hypothesis kruskal_hypothesis
# column
# age                     1.305708e-74       alternative        alternative
# income                  7.188400e-01              null               null
# spending_score          1.598997e-01              null               null
# membership_years        5.942733e-01              null               null
# purchase_frequency      6.589960e-01              null               null
# last_purchase_amount    3.697276e-01              null               null
